# %%
Introduction:The project aims to analyze the dataset containing information about bank clients, focusing on understanding the relationships between different variables and identifying any significant correlations.
The analysis uses correlation analysis to gain insights into the factors that may influence customer behavior and banking metrics.
Tools used:
Python programming language
Pandas for data manipulation
Matplotlib and Seaborn for data visualization.
Target:
The primary goal of this project is to explore the dataset and identify any variables that are highly correlated.
By understanding these correlations, we can gain insights into the relationships between different attributes of bank clients and potentially uncover factors that contribute to customer behavior,such as attrition.

# %% [markdown]
# # Brief introduction of the column:

# %%
CLIENTNUM: Unique identifier for each client or customer.
Attrition_Flag: Binary variable indicating whether the customer has churned (attrition) or not.
Customer_Age: Age of the customer.
Gender: Gender of the customer.
Dependent_count: Number of dependents of the customer.
Education_Level: Education level of the customer.
Marital_Status: Marital status of the customer.
Income_Category: Income category of the customer.
Card_Category: Category of the credit card the customer holds.
Months_on_book: Number of months the customer has been a client.
Total_Relationship_Count: Total number of products held by the customer.
Months_Inactive_12_mon: Number of months with no transaction activity in the last 12 months.
Contacts_Count_12_mon: Number of contacts or interactions with the customer in the last 12 months.
Credit_Limit: Credit limit for the customer.
Total_Revolving_Bal: Total revolving balance on the credit card.
Avg_Open_To_Buy: Average open-to-buy credit line (Credit_Limit - Total_Revolving_Bal).
Total_Trans_Amt: Total transaction amount in the last 12 months.
Total_Trans_Ct: Total number of transactions in the last 12 months.
Avg_Utilization_Ratio: Average utilization ratio of the credit card.

# %% [markdown]
# # import Libraries and Load data

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# load the data and save it into the dataframe:
customer_data=pd.read_csv(r'C:\Users\91902\Downloads\Customer_churned.csv')

# %%
customer_data
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# Display the first few rows of the dataset to understand its structure with the help of the function df.head()
customer_data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
#check the shape of the dataframe like display all the number of rows and columns in the DataFrame using df.shape()
customer_data.shape
# Out:
# (10127, 19)

# %%
#Display the dimension of the DataFrame using df.ndim
customer_data.ndim
# Out:
# 2

# %%
# Display the summary of the dataframe including the datatypes of each column ,the number of non-nulll values and also the memory usage
#It's useful for quickly understanding the overall structure of the dataframe and identifying the missing values
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10034 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             9995 non-null   object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
customer_data.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
#describe().T is used to view some basic statistical summaries like percentile,mean,std.etc.,of a dataframe or a series of numeric values
customer_data.describe().T
# Out:
#                             count          mean           std          min  \
# CLIENTNUM                 10127.0  7.391776e+08  3.690378e+07  708082083.0
# Customer_Age              10127.0  4.728528e+01  1.327092e+01         26.0
# Dependent_count           10127.0  2.787400e+00  6.479135e+00          0.0
# Months_on_book            10127.0  3.592841e+01  7.986416e+00         13.0
# Total_Relationship_Count  10127.0  3.812580e+00  1.554408e+00          1.0
# Months_Inactive_12_mon    10127.0  2.341167e+00  1.010622e+00          0.0
# Contacts_Count_12_mon     10127.0  2.455317e+00  1.106225e+00          0.0
# Credit_Limit              10067.0  8.703181e+03  9.190059e+03       1438.3
# Total_Revolving_Bal       10127.0  1.162814e+03  8.149873e+02          0.0
# Avg_Open_To_Buy           10127.0  7.469140e+03  9.090685e+03          3.0
# Total_Trans_Amt           10127.0  4.404086e+03  3.397129e+03        510.0
# ...

# %% [markdown]
# # DATA CLEANING

# %%
#check null values 
customer_data.isnull().sum()
# Out:
# CLIENTNUM                     0
# Attrition_Flag                0
# Customer_Age                  0
# Gender                       93
# Dependent_count               0
# Education_Level               0
# Marital_Status                0
# Income_Category               0
# Card_Category               132
# Months_on_book                0
# Total_Relationship_Count      0
# Months_Inactive_12_mon        0
# Contacts_Count_12_mon         0
# Credit_Limit                 60
# Total_Revolving_Bal           0
# Avg_Open_To_Buy               0
# Total_Trans_Amt               0
# Total_Trans_Ct                0
# Avg_Utilization_Ratio         0
# dtype: int64

# %%
#NULl value treatment:
customer_data['Gender'].fillna(customer_data['Gender'].mode()[0],inplace=True)
customer_data['Card_Category'].fillna(customer_data['Card_Category'].mode()[0],inplace=True)
customer_data['Credit_Limit'].fillna(customer_data['Credit_Limit'].median(),inplace=True)

# %%
# Check for missing values again
customer_data.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
#check duplicates
customer_data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10122    False
# 10123    False
# 10124    False
# 10125    False
# 10126    False
# Length: 10127, dtype: bool

# %%
import numpy as np
customer_data['Credit_Limit'] = customer_data['Credit_Limit'].replace('', np.nan)#after using mode ,mean,median the credit_limit has still nullvalues so using other function for removing white space and extra space

# %%
# After using the functions still the nullvalue remains same so we can use dropna function to drop all the null values:
customer_data=customer_data.dropna(subset=['Credit_Limit'])

# %%
#identify the categorical and numerical data
cat=[]
num=[]
def data_type(df):
    for col in df.columns:
        if df[col].nunique()<30:
            cat.append(col)
        else:
            num.append(col)
            
data_type(customer_data)

# %%
cat
# Out:
# ['Attrition_Flag',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category',
#  'Total_Relationship_Count',
#  'Months_Inactive_12_mon',
#  'Contacts_Count_12_mon']

# %%
num
# Out:
# ['CLIENTNUM',
#  'Customer_Age',
#  'Dependent_count',
#  'Months_on_book',
#  'Credit_Limit',
#  'Total_Revolving_Bal',
#  'Avg_Open_To_Buy',
#  'Total_Trans_Amt',
#  'Total_Trans_Ct',
#  'Avg_Utilization_Ratio']

# %%
def mode_cat(cat):
    for col in cat:
        print(f'{col},Mode={customer_data[col].mode()[0]},Nunique {customer_data[col].nunique()} , Missing_Val {customer_data[col].isnull().sum()}')
        
mode_cat(cat)
# Out:
# Attrition_Flag,Mode=Existing Customer,Nunique 2 , Missing_Val 0
# Gender,Mode=F,Nunique 2 , Missing_Val 0
# Education_Level,Mode=Graduate,Nunique 7 , Missing_Val 0
# Marital_Status,Mode=Married,Nunique 4 , Missing_Val 0
# Income_Category,Mode=Less than $40K,Nunique 6 , Missing_Val 0
# Card_Category,Mode=Blue,Nunique 4 , Missing_Val 0
# Total_Relationship_Count,Mode=3,Nunique 6 , Missing_Val 0
# Months_Inactive_12_mon,Mode=3,Nunique 7 , Missing_Val 0
# Contacts_Count_12_mon,Mode=3,Nunique 7 , Missing_Val 0

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate Analysis

# %%
# Distribution of Customer Age
plt.figure(figsize=(10, 6))
sns.histplot(customer_data['Customer_Age'], bins=20, kde=True)
plt.title('Distribution of Customer Age')
plt.show()

# %%
# Count of Attrition_Flag
plt.figure(figsize=(6, 4))
sns.countplot(x='Attrition_Flag', data=customer_data)
plt.title('Count of Attrition_Flag')
plt.show()

# %%
# Income Category Distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Income_Category', data=customer_data)
plt.xticks(rotation=45)
plt.title('Income Category Distribution')
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
# Relationship between Age and Total Transaction Amount
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Customer_Age', y='Total_Trans_Amt', data=customer_data, hue='Attrition_Flag')
plt.title('Age vs Total Transaction Amount')
plt.show()

# %% [markdown]
# # Handling Categorical Data

# %%
# One-Hot Encoding for categorical columns
customer_data_encoded = pd.get_dummies(customer_data, columns=['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category'])

# %%
num
# Out:
# ['CLIENTNUM',
#  'Customer_Age',
#  'Dependent_count',
#  'Months_on_book',
#  'Credit_Limit',
#  'Total_Revolving_Bal',
#  'Avg_Open_To_Buy',
#  'Total_Trans_Amt',
#  'Total_Trans_Ct',
#  'Avg_Utilization_Ratio']

# %%
# Correlation Analysis:
correlation_matrix=customer_data[['CLIENTNUM',
 'Customer_Age',
 'Dependent_count',
 'Months_on_book',
 'Credit_Limit',
 'Total_Revolving_Bal',
 'Avg_Open_To_Buy',
 'Total_Trans_Amt',
 'Total_Trans_Ct',
 'Avg_Utilization_Ratio']].corr()
print(correlation_matrix)
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm')
plt.show()
# Out:
#                        CLIENTNUM  Customer_Age  Dependent_count  \
# CLIENTNUM               1.000000     -0.002868         0.007106
# Customer_Age           -0.002868      1.000000        -0.013227
# Dependent_count         0.007106     -0.013227         1.000000
# Months_on_book          0.134588      0.467021        -0.011629
# Credit_Limit            0.004323      0.000156         0.010475
# Total_Revolving_Bal     0.000825      0.001316        -0.006408
# Avg_Open_To_Buy         0.005633     -0.002013         0.001775
# Total_Trans_Amt        -0.019692     -0.016087         0.011953
# Total_Trans_Ct         -0.002961     -0.037657         0.022722
# Avg_Utilization_Ratio   0.000266      0.008250        -0.013912
#
#                        Months_on_book  Credit_Limit  Total_Revolving_Bal  \
# CLIENTNUM                    0.134588      0.004323             0.000825
# Customer_Age                 0.467021      0.000156             0.001316
# ...

# %%
Conclusion:
The correlation analysis revealed that some variables in the dataset are highly correlated, with a correlation coefficient of 1.
This suggests a perfect linear relationship between these variables.
While further analysis is needed to understand the underlying causes of these correlations, these findings provide valuable insights into the factors that may influence customer behavior in the banking industry.
